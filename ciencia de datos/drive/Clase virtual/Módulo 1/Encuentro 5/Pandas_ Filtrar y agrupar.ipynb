# %% [markdown]
# #### Dataset
#
# Hoy aprenderemos a filtrar un dataset y realizar agrupaciones con métodos de la librería de pandas.
#
# Retomaremos el dataset utilizado la clase anterior sobre Encuentros de educación ambiental extraído de https://datos.gob.ar/dataset/ambiente-encuentros-jornadas-educacion-ambiental

# %%
#importamos las librerias que utilizaremos
import pandas as pd

# %% [markdown]
# #### Desde el Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = pd.read_csv("/content/drive/MyDrive/Módulo 1/Encuentro 5/Encuentros educación ambiental.csv",  sep=";") #aclaración punto y coma en este archivo

# %% [markdown]
# #### Desde el archivo descargado en la computadora

# %%
from google.colab import files
import io

# %%
filesUploaded = files.upload()
# Out:
#      <input type="file" id="files-730bc067-f863-49e0-a6d8-4484a83de138" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-730bc067-f863-49e0-a6d8-4484a83de138">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
data = pd.read_csv(io.BytesIO(filesUploaded["encuentro-educacion-ambiental.csv"]), sep=";")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-ff720fe7f816> in <module>()
# ----> 1 data = pd.read_csv(io.BytesIO(filesUploaded["encuentro-educacion-ambiental.csv"]), sep=";")
#
# KeyError: 'encuentro-educacion-ambiental.csv'

# %%
data.head(3)
# Out:
#    encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0            2016                 1                       90
# 1            2016                 1                       90
# 2            2016                 1                      400
#
#                                   encuentro_tematica  \
# 0                           Encuentro Nacional de EA
# 1                             Jornada ODS y ambiente
# 2  Jornadas internacionales de Emprendedurismo es...
#
#                              Encuentro_destinatarios
# 0  Funcionarios de los Ministerios de Ambiente y ...
# 1  Funcionarios, educadores, empresarios, periodi...
# 2                        Alumnos de nivel secundario

# %% [markdown]
# ### Filtrar un dataset
#
# #### .iloc
#
# Para acceder a determinadas columnas, filas o registros de un dataset es posible indexarlos por número de fila y número de columna a través del método *.iloc* y entre corchetes separado por una coma primero las filas y luego las columnas.
#
# Además es posible utilizar un *slice*, es decir, seleccionar filas o columnas  donde se indique desde y hasta cual. Para eso se coloca un valor, dos puntos y el segundo valor, siendo el primero inclusivo y el último no inclusivo).
#
# Para seleccionar todas las filas o todas las columnas debo colocar hacer un slice sin límite, es decir solo : (dos puntos)

# %%
data
# Out:
#     encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0             2016                 1                       90
# 1             2016                 1                       90
# 2             2016                 1                      400
# 3             2017                 4                      250
# 4             2017                 2                     3000
# 5             2017                 2                      130
# 6             2017                 1                       22
# 7             2017                 1                      700
# 8             2018                 8                      540
# 9             2018                 2                      150
# 10            2018                10                      350
# 11            2018                 1                      170
# 12            2019                 1                      220
# 13            2019                 2                       20
# 14            2019                 2                       50
# 15            2019                 7                       80
#
#                                    encuentro_tematica  \
# 0                            Encuentro Nacional de EA
# 1                              Jornada ODS y ambiente
# 2   Jornadas internacionales de Emprendedurismo es...
# 3   Estrategia Nacional de EA/Encuentros regionale...
# 4                           Eventos con Universidades
# 5                             ODS y sector empresario
# 6                          EA y edificios sutentables
# 7                                Jornadas Municipales
# 8   Estrategia Nacional de EA/Encuentros regionale...
# 9     MESAS DE DIÁLOGO INTERSECOTRIAL LAUDATOS SÍ-ODS
# 10  Estrategia Nacional para la Sustentabilidad en...
# 11  Encuentro de Educación Ambiental y Exóticas In...
# 12                           Encuentro Nacional de EA
# 13  Estrategia Nacional de EA/Encuentros provincia...
# 14  Estrategia Nacional para la Sustentabilidad en...
# 15  Mesa intraministerial de gènero ambiente y des...
#
#                               Encuentro_destinatarios
# 0   Funcionarios de los Ministerios de Ambiente y ...
# 1   Funcionarios, educadores, empresarios, periodi...
# 2                         Alumnos de nivel secundario
# 3   Funcionarios de los Ministerios de Ambiente y ...
# 4   Autoridades provinciales/Autoridades y docente...
# 5                         Emprendedores y empresarios
# 6                      Guías del museo de Casa Rosada
# 7   Funcionarios provinciales y municipales. Insti...
# 8   Funcionarios de los Ministerios de Ambiente y ...
# 9   Funcionarios, educadores, empresarios, referen...
# 10              Autoridades y docentes universitarios
# 11  Funcionarios, educadores, periodistas, cientìf...
# 12  Funcionarios de los Ministerios de Ambiente y ...
# 13   Funcionarios provinciales de Educaciòn Ambiental
# 14              Autoridades y docentes universitarios
# 15                              Funcionarios públicos

# %%
#iloc: acceso por número de fila, columna
data.iloc[1,3] # range(inicio,final,step)
# Out:
# 'Jornada ODS y ambiente'

# %%
#slice entre fila 1 a 4 (no inclusivo), columa 3
data.iloc[1, 1:4]
# Out:
# encuentro_numero                                1
# encuentro_participantes                        90
# encuentro_tematica         Jornada ODS y ambiente
# Name: 1, dtype: object

# %%
# Seleccionar la fila 4 y todas sus columnas  (si no se coloca nada se asume que son todas las columnas)

data.iloc[4, :]
# Out:
# encuentro_anio                                                          2017
# encuentro_numero                                                           2
# encuentro_participantes                                                 3000
# encuentro_tematica                                 Eventos con Universidades
# Encuentro_destinatarios    Autoridades provinciales/Autoridades y docente...
# Name: 4, dtype: object

# %%
# Para filtrar la columna se debe colocar : en lugar de las filas

data.iloc[:, 2]
# Out:
# 0       90
# 1       90
# 2      400
# 3      250
# 4     3000
# 5      130
# 6       22
# 7      700
# 8      540
# 9      150
# 10     350
# 11     170
# 12     220
# 13      20
# 14      50
# 15      80
# Name: encuentro_participantes, dtype: int64

# %%
data[1:6]
# Out:
#    encuentro_anio  encuentro_numero  encuentro_participantes  \
# 1            2016                 1                       90
# 2            2016                 1                      400
# 3            2017                 4                      250
# 4            2017                 2                     3000
# 5            2017                 2                      130
#
#                                   encuentro_tematica  \
# 1                             Jornada ODS y ambiente
# 2  Jornadas internacionales de Emprendedurismo es...
# 3  Estrategia Nacional de EA/Encuentros regionale...
# 4                          Eventos con Universidades
# 5                            ODS y sector empresario
#
#                              Encuentro_destinatarios
# 1  Funcionarios, educadores, empresarios, periodi...
# 2                        Alumnos de nivel secundario
# 3  Funcionarios de los Ministerios de Ambiente y ...
# 4  Autoridades provinciales/Autoridades y docente...
# 5                        Emprendedores y empresarios

# %% [markdown]
# #### .loc
# Es posible filtrar por columnas, filas o registros utilizando el nombre de las columnas utilizando el método *.loc* y entre corchetes primero las filas y luego las columnas

# %%
#fila 1, columa "encuentro_tematica"
data.loc[1,"encuentro_tematica"]
# Out:
# 'Jornada ODS y ambiente'

# %%
# Para ver todos los registros se debe indicar : en el lugar de las filas

data.loc[:, "encuentro_tematica"]
# Out:
# 0                              Encuentro Nacional de EA
# 1                                Jornada ODS y ambiente
# 2     Jornadas internacionales de Emprendedurismo es...
# 3     Estrategia Nacional de EA/Encuentros regionale...
# 4                             Eventos con Universidades
# 5                               ODS y sector empresario
# 6                            EA y edificios sutentables
# 7                                  Jornadas Municipales
# 8     Estrategia Nacional de EA/Encuentros regionale...
# 9       MESAS DE DIÁLOGO INTERSECOTRIAL LAUDATOS SÍ-ODS
# 10    Estrategia Nacional para la Sustentabilidad en...
# 11    Encuentro de Educación Ambiental y Exóticas In...
# 12                             Encuentro Nacional de EA
# 13    Estrategia Nacional de EA/Encuentros provincia...
# 14    Estrategia Nacional para la Sustentabilidad en...
# 15    Mesa intraministerial de gènero ambiente y des...
# Name: encuentro_tematica, dtype: object

# %%
 # Se puede seleccionar una lista de columnas

 data.loc[0:10, "encuentro_numero":"encuentro_tematica"]

 #Notese que se puede hacer sin el loc como vimos la Notebook anterior
# Out:
#     encuentro_numero  encuentro_participantes  \
# 0                  1                       90
# 1                  1                       90
# 2                  1                      400
# 3                  4                      250
# 4                  2                     3000
# 5                  2                      130
# 6                  1                       22
# 7                  1                      700
# 8                  8                      540
# 9                  2                      150
# 10                10                      350
#
#                                    encuentro_tematica
# 0                            Encuentro Nacional de EA
# 1                              Jornada ODS y ambiente
# 2   Jornadas internacionales de Emprendedurismo es...
# 3   Estrategia Nacional de EA/Encuentros regionale...
# 4                           Eventos con Universidades
# 5                             ODS y sector empresario
# 6                          EA y edificios sutentables
# 7                                Jornadas Municipales
# 8   Estrategia Nacional de EA/Encuentros regionale...
# 9     MESAS DE DIÁLOGO INTERSECOTRIAL LAUDATOS SÍ-ODS
# 10  Estrategia Nacional para la Sustentabilidad en...

# %% [markdown]
# #### Filtrar un DataFrame
#
# Para realizar un filtro de determinados valores se debe generar máscara con una operación lógica que devuelva *True* o *False*.
#
# Luego se debe usar el método *.loc* con la máscara donde los valores *True* los tomará y los valores *False* los descartará

# %%
#filtrar 2016
print(data["encuentro_anio"])
mask_2016 = data["encuentro_anio"]== 2016   #ver el doble igual. Como es un número no requiere las comillas
mask_2016
# Out:
# 0     2016
# 1     2016
# 2     2016
# 3     2017
# 4     2017
# 5     2017
# 6     2017
# 7     2017
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2019
# 13    2019
# 14    2019
# 15    2019
# Name: encuentro_anio, dtype: int64
# 0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: encuentro_anio, dtype: bool

# %%
#solo devuelvo los valores True (evalua por índice)
data.loc[mask_2016]
# Out:
#    encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0            2016                 1                       90
# 1            2016                 1                       90
# 2            2016                 1                      400
#
#                                   encuentro_tematica  \
# 0                           Encuentro Nacional de EA
# 1                             Jornada ODS y ambiente
# 2  Jornadas internacionales de Emprendedurismo es...
#
#                              Encuentro_destinatarios
# 0  Funcionarios de los Ministerios de Ambiente y ...
# 1  Funcionarios, educadores, empresarios, periodi...
# 2                        Alumnos de nivel secundario

# %%
#por default sin el .loc selecciona filas True
data[mask_2016]
# Out:
#    encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0            2016                 1                       90
# 1            2016                 1                       90
# 2            2016                 1                      400
#
#                                   encuentro_tematica  \
# 0                           Encuentro Nacional de EA
# 1                             Jornada ODS y ambiente
# 2  Jornadas internacionales de Emprendedurismo es...
#
#                              Encuentro_destinatarios
# 0  Funcionarios de los Ministerios de Ambiente y ...
# 1  Funcionarios, educadores, empresarios, periodi...
# 2                        Alumnos de nivel secundario

# %%
#loc[filas (True), columnas]
data.loc[mask_2016,"encuentro_tematica"]
# Out:
# 0                             Encuentro Nacional de EA
# 1                               Jornada ODS y ambiente
# 2    Jornadas internacionales de Emprendedurismo es...
# Name: encuentro_tematica, dtype: object

# %%
#error sin el loc
data[mask_2016,"encuentro_tematica"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-6797fc4d1548> in <module>()
#       1 #error sin el loc
# ----> 2 data[mask_2016,"encuentro_tematica"]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0      True
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: encuentro_anio, dtype: bool, 'encuentro_tematica')' is an invalid key

# %%
#error con iloc
data.iloc[mask_2016]

# %%
#creo dataframe filtrado 2016

data_2016 = data.loc[mask_2016]
data_2016

# %%
# Puedo utilizar una operación matemática sobre el DataFrame filtrado. ¿Cuántos encuentros se realizaron en 2016?
data_2016["encuentro_numero"].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-00db36c6ecbf> in <module>()
#       1 # Puedo utilizar una operación matemática sobre el DataFrame filtrado. ¿Cuántos encuentros se realizaron en 2016?
# ----> 2 data_2016["encuentro_numero"].sum()
#
# NameError: name 'data_2016' is not defined

# %%
#cuantos participaron en los encuentros de 2016
data_2016["encuentro_participantes"].sum()

# %%
#en una sola linea
data.loc[mask_2016,"encuentro_participantes"].sum()

# %%
data.loc[,"encuentro_participantes"].sum()

# %%
#ver el encuentro con mayor cantidad de participantes
data["encuentro_participantes"].max()
# Out:
# 3000

# %%
#Definición de operación lógica con ==

mask_max_participantes = data["encuentro_participantes"]== data["encuentro_participantes"].max()
mask_max_participantes
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: encuentro_participantes, dtype: bool

# %%
data[mask_max_participantes]
#data.loc[mask_max_participantes]
# Out:
#    encuentro_anio  encuentro_numero  encuentro_participantes  \
# 4            2017                 2                     3000
#
#           encuentro_tematica  \
# 4  Eventos con Universidades
#
#                              Encuentro_destinatarios
# 4  Autoridades provinciales/Autoridades y docente...

# %%
#temática del encuentro con mayor cantidad de participantes
data.loc[mask_max_participantes, "encuentro_tematica"]
# Out:
# 4    Eventos con Universidades
# Name: encuentro_tematica, dtype: object

# %%
data
# Out:
#     encuentro_anio  encuentro_numero  encuentro_participantes  \
# 0             2016                 1                       90
# 1             2016                 1                       90
# 2             2016                 1                      400
# 3             2017                 4                      250
# 4             2017                 2                     3000
# 5             2017                 2                      130
# 6             2017                 1                       22
# 7             2017                 1                      700
# 8             2018                 8                      540
# 9             2018                 2                      150
# 10            2018                10                      350
# 11            2018                 1                      170
# 12            2019                 1                      220
# 13            2019                 2                       20
# 14            2019                 2                       50
# 15            2019                 7                       80
#
#                                    encuentro_tematica  \
# 0                            Encuentro Nacional de EA
# 1                              Jornada ODS y ambiente
# 2   Jornadas internacionales de Emprendedurismo es...
# 3   Estrategia Nacional de EA/Encuentros regionale...
# 4                           Eventos con Universidades
# 5                             ODS y sector empresario
# 6                          EA y edificios sutentables
# 7                                Jornadas Municipales
# 8   Estrategia Nacional de EA/Encuentros regionale...
# 9     MESAS DE DIÁLOGO INTERSECOTRIAL LAUDATOS SÍ-ODS
# 10  Estrategia Nacional para la Sustentabilidad en...
# 11  Encuentro de Educación Ambiental y Exóticas In...
# 12                           Encuentro Nacional de EA
# 13  Estrategia Nacional de EA/Encuentros provincia...
# 14  Estrategia Nacional para la Sustentabilidad en...
# 15  Mesa intraministerial de gènero ambiente y des...
#
#                               Encuentro_destinatarios
# 0   Funcionarios de los Ministerios de Ambiente y ...
# 1   Funcionarios, educadores, empresarios, periodi...
# 2                         Alumnos de nivel secundario
# 3   Funcionarios de los Ministerios de Ambiente y ...
# 4   Autoridades provinciales/Autoridades y docente...
# 5                         Emprendedores y empresarios
# 6                      Guías del museo de Casa Rosada
# 7   Funcionarios provinciales y municipales. Insti...
# 8   Funcionarios de los Ministerios de Ambiente y ...
# 9   Funcionarios, educadores, empresarios, referen...
# 10              Autoridades y docentes universitarios
# 11  Funcionarios, educadores, periodistas, cientìf...
# 12  Funcionarios de los Ministerios de Ambiente y ...
# 13   Funcionarios provinciales de Educaciòn Ambiental
# 14              Autoridades y docentes universitarios
# 15                              Funcionarios públicos

# %%
#buscar temáticas de ecuentros para Autoridades y docentes universitarios. Se puede hacer la máscara en la misma fila que el loc

data.loc[(data["Encuentro_destinatarios"]=="Autoridades y docentes universitarios"), "encuentro_tematica"]
# Out:
# 10    Estrategia Nacional para la Sustentabilidad en...
# 14    Estrategia Nacional para la Sustentabilidad en...
# Name: encuentro_tematica, dtype: object

# %%
#cuantos participantes de los encuentros para Autoridades y docentes universitarios
data.loc[(data["Encuentro_destinatarios"]=="Autoridades y docentes universitarios"), "encuentro_participantes"].sum()
# Out:
# 400

# %% [markdown]
# #### Agrupación
#
# El método _groupby_agrupa todas las filas que tengan igual valor. [Documentacion groupby](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html?highlight=groupby#pandas.DataFrame.groupby)
#
#
# Podemos describir las operaciones sobre grupos con el término *split-apply-combine*
#
# En la primera etapa del proceso, los datos en un objeto `pandas` (una instancia de `Series` o de `DataFrame`) se dividen en grupos (*split*) en base a una o más keys que definimos. Esta división se lleva a cabo por filas (axis = 0) o por columnas (axis = 1).
#
# Como segunda etapa, aplicamos una función a cada uno de los grupos (*apply*) dando como resultado un nuevo valor por grupo.
#
# Como último paso, los resultados de la aplicación de la función en cada uno de los grupos se combina en un objeto resultado (*combine*).

# %%
#agrupamos la tabla por año
data_agrupada = data.groupby("encuentro_anio")
data_agrupada

#Acá se crea un objeto agrupado por encuentro pero aún o hemos realizado ninguna operación para poner datos
#Sería como una tabla que solamente tiene un índice y falta indicar los datos

# %%
data.encuentro_anio
# Out:
# 0     2016
# 1     2016
# 2     2016
# 3     2017
# 4     2017
# 5     2017
# 6     2017
# 7     2017
# 8     2018
# 9     2018
# 10    2018
# 11    2018
# 12    2019
# 13    2019
# 14    2019
# 15    2019
# Name: encuentro_anio, dtype: int64

# %%
#cuántos valores de cada año
data_agrupada.size()
# Out:
# encuentro_anio
# 2016    3
# 2017    5
# 2018    4
# 2019    4
# dtype: int64

# %%
# sobre esta agrupación podemos realizar distintos operaciones, por ejemplo sumar la cantidad de participantes por año (por agrupación)
data_agrupada["encuentro_participantes"].sum()
# Out:
# encuentro_anio
# 2016     580
# 2017    4102
# 2018    1210
# 2019     370
# Name: encuentro_participantes, dtype: int64

# %%
#creo un DataFrame de la data agrupada por año, ver que tiene un índice y una columna
data_anio_encuentro =data_agrupada["encuentro_participantes"].sum()
print(data_anio_encuentro.shape)
data_anio_encuentro
# Out:
# (4,)
# encuentro_anio
# 2016     580
# 2017    4102
# 2018    1210
# 2019     370
# Name: encuentro_participantes, dtype: int64

# %%
# Vamos a agrupar los encuentros por destinatario, primero observamos cuantos hay de cada tipo

data["Encuentro_destinatarios"].value_counts()
# Out:
# Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC    4
# Autoridades y docentes universitarios                                        2
# Funcionarios, educadores, empresarios, periodistas                           1
# Alumnos de nivel secundario                                                  1
# Autoridades provinciales/Autoridades y docentes universitarias               1
# Emprendedores y empresarios                                                  1
# Guías del museo de Casa Rosada                                               1
# Funcionarios provinciales y municipales. Instituciones educativas, OSC       1
# Funcionarios, educadores, empresarios, referentes religiosos                 1
# Funcionarios, educadores, periodistas, cientìficos                           1
# Funcionarios provinciales de Educaciòn Ambiental                             1
# Funcionarios públicos                                                        1
# Name: Encuentro_destinatarios, dtype: int64

# %%
# realizamos la agrupación utilizando el método groupby

data_destinantarios = data.groupby("Encuentro_destinatarios")
data_destinantarios.size()

# ¿Cuántas filas debería tener la agrupación? Observar el value_counts()
# Out:
# Encuentro_destinatarios
# Alumnos de nivel secundario                                                  1
# Autoridades provinciales/Autoridades y docentes universitarias               1
# Autoridades y docentes universitarios                                        2
# Emprendedores y empresarios                                                  1
# Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC    4
# Funcionarios provinciales de Educaciòn Ambiental                             1
# Funcionarios provinciales y municipales. Instituciones educativas, OSC       1
# Funcionarios públicos                                                        1
# Funcionarios, educadores, empresarios, periodistas                           1
# Funcionarios, educadores, empresarios, referentes religiosos                 1
# Funcionarios, educadores, periodistas, cientìficos                           1
# Guías del museo de Casa Rosada                                               1
# dtype: int64

# %%
# Hacer una operación: sumar la cantidad de encuentros 

data_destinantarios["encuentro_participantes"].sum()
# Out:
# Encuentro_destinatarios
# Alumnos de nivel secundario                                                   400
# Autoridades provinciales/Autoridades y docentes universitarias               3000
# Autoridades y docentes universitarios                                         400
# Emprendedores y empresarios                                                   130
# Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC    1100
# Funcionarios provinciales de Educaciòn Ambiental                               20
# Funcionarios provinciales y municipales. Instituciones educativas, OSC        700
# Funcionarios públicos                                                          80
# Funcionarios, educadores, empresarios, periodistas                             90
# Funcionarios, educadores, empresarios, referentes religiosos                  150
# Funcionarios, educadores, periodistas, cientìficos                            170
# Guías del museo de Casa Rosada                                                 22
# Name: encuentro_participantes, dtype: int64

# %%
# Hacer una operación: el primer año en el que se desarrollaron encuentros

data_destinantarios["encuentro_anio"].min()
# Out:
# Encuentro_destinatarios
# Alumnos de nivel secundario                                                  2016
# Autoridades provinciales/Autoridades y docentes universitarias               2017
# Autoridades y docentes universitarios                                        2018
# Emprendedores y empresarios                                                  2017
# Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC    2016
# Funcionarios provinciales de Educaciòn Ambiental                             2019
# Funcionarios provinciales y municipales. Instituciones educativas, OSC       2017
# Funcionarios públicos                                                        2019
# Funcionarios, educadores, empresarios, periodistas                           2016
# Funcionarios, educadores, empresarios, referentes religiosos                 2018
# Funcionarios, educadores, periodistas, cientìficos                           2018
# Guías del museo de Casa Rosada                                               2017
# Name: encuentro_anio, dtype: int64

# %% [markdown]
# ### Ejercicios
#  1. ¿Cuáles son los posibles destinatarios?
#
#  2. Mostrar la información de los encuentros del año 2019. *Crear una máscara y luego acceder con .loc*
#
#  3. Crea un Dafreame con los destinatarios de los encuentros del año 2019.
#
#  4. ¿Cuántos encuentros hubo en el año 2018?
#
#  5. ¿Cuántos encuentros hubo para "Almunos de nivel secundario"? *Realizaro con sum() y luego crea un Dataframe con la información de este/esos encuentro/s*
#
#  6. ¿Cuántos participantes promedio hubo por año? *usar groupby*
#
#  7. ¿Cuántos participantes de cada destinatario hubo? *usar groupby*
#
#  8. ¿Cuántos participantes hubo por año por destinatario por año? *para hacer agrupaciones sobre 2 columnas se deben colocar entre corchetes dentro del parentesis (["columa1", "columna2"])*

# %%
data.columns
# Out:
# Index(['encuentro_anio', 'encuentro_numero', 'encuentro_participantes',
#        'encuentro_tematica', 'Encuentro_destinatarios'],
#       dtype='object')

# %%
data.groupby(['encuentro_anio','Encuentro_destinatarios'])['encuentro_participantes'].sum()
# Out:
# encuentro_anio  Encuentro_destinatarios
# 2016            Alumnos de nivel secundario                                                   400
#                 Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC      90
#                 Funcionarios, educadores, empresarios, periodistas                             90
# 2017            Autoridades provinciales/Autoridades y docentes universitarias               3000
#                 Emprendedores y empresarios                                                   130
#                 Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC     250
#                 Funcionarios provinciales y municipales. Instituciones educativas, OSC        700
#                 Guías del museo de Casa Rosada                                                 22
# 2018            Autoridades y docentes universitarios                                         350
#                 Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC     540
#                 Funcionarios, educadores, empresarios, referentes religiosos                  150
#                 Funcionarios, educadores, periodistas, cientìficos                            170
# 2019            Autoridades y docentes universitarios                                          50
#                 Funcionarios de los Ministerios de Ambiente y Educación/Universidades/OSC     220
#                 Funcionarios provinciales de Educaciòn Ambiental                               20
#                 Funcionarios públicos                                                          80
# Name: encuentro_participantes, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# pip install pyqt5

# %%
# %matplotlib qt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-42-d5b5e19d67a5> in <module>()
# ----> 1 get_ipython().magic('matplotlib qt')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in magic(self, arg_s)
#    2158         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2159         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2160         return self.run_line_magic(magic_name, magic_arg_s)
#    2161
#    2162     #-------------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line)
#    2079                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2080             with self.builtin_trap:
# -> 2081                 result = fn(*args,**kwargs)
#    2082             return result
#    2083
#
# <decorator-gen-98> in matplotlib(self, line)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py in matplotlib(self, line)
#      98             print("Available matplotlib backends: %s" % backends_list)
#      99         else:
# --> 100             gui, backend = self.shell.enable_matplotlib(args.gui)
#     101             self._show_matplotlib_backend(args.gui, backend)
#     102
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in enable_matplotlib(self, gui)
#    2948                 gui, backend = pt.find_gui_and_backend(self.pylab_gui_select)
#    2949
# -> 2950         pt.activate_matplotlib(backend)
#    2951         pt.configure_inline_support(self, backend)
#    2952
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/pylabtools.py in activate_matplotlib(backend)
#     307
#     308     import matplotlib.pyplot
# --> 309     matplotlib.pyplot.switch_backend(backend)
#     310
#     311     # This must be imported last in the matplotlib series, after
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     235                 "Cannot load backend {!r} which requires the {!r} interactive "
#     236                 "framework, as {!r} is currently running".format(
# --> 237                     newbackend, required_framework, current_framework))
#     238
#     239     rcParams['backend'] = rcParamsDefault['backend'] = newbackend
#
# ImportError: Cannot load backend 'Qt5Agg' which requires the 'qt5' interactive framework, as 'headless' is currently running
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
