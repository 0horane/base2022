# %% [markdown]
# ### Proyecto Módulo 1
#
# Esta Notebook es una guía de ejercicios para ir realizando a lo largo del primer módulo que servirá para practicar la escritura del código e ir viendo las aplicaciones.

# %% [markdown]
# ### Ejercicios Tipos de datos
#
# 1. Hacer una lista que contenga 3 materias de la escuela
#
# 2. Eliminar el primer registro de la lista
#
# 3. Agregar una materia más al final
#
# 4. Seleccionar el segundo elemento de la lista
#
# 5. Crear un diccionario con las materias y el nombre del/la profesor/a
#
# 6. Agregar una materia y un/a profesora/
#
# 7. Eliminar una materia y un/a profesor/a

# %%
#1
materias = ["matematica", "lengua", "ingles"]
#2
materias.pop(0)
#3
materias.append("historia")
#4
materias[1]
#5
dictmaterias = {"matematica": "capalbo", "lengua":"ponzo", "historia": "sarella"}
#6
dictmaterias["ingles"]="migale"
#7
dictmaterias.pop("lengua")
# Out:
# 'ponzo'

# %% [markdown]
# ### Ejericicios estructuras de control
#
# 1. Definir 2 variables con números (num1 y num2). Crear una estructura condicional donde si los dos números son iguales se imprima "los dos números son iguales" (*if... else...*)
#
# 2. Crear una estructura condicional donde si "no llueve", "podemos ir a la plaza" y sino "debemos quedarnos en casa" (*if... else...*)
#
# 3. Definir una lista con 3 números (puede ser la misma que antes). Crear una estructura iterativa donde se imprima cada número +2 (*for... in...*)
#
# 4. Crear una lista con 5 materias de la escuela. Crear una estructura interativa que permita CONTAR la cantidad de elementos en la lista (*for... in...*)
#
# 5. Crea una función que divida dos números que reciba como parámetros
#
# 6. Crea una función que reciba 2 números e incluya un condicional donde si el segundo número es 0 imprima "no se puede realizar esta operación" y sino realice una división entre el primer y el segundo número.
#
# 7. Crear una función que dada una lista de números y un número (parámetros), agregue el número a la lista (*def*)

# %%
#1 
num1=10
num2=11
if num1 == num2:
    print("los dos numeros son iguales")
else:
    print("los dos numeros son diferentes")

#2
tiempo = "no llueve"
if tiempo == "no llueve":
    print("podemos ir a la plaza")
else: 
    print("debemos quedarnos en casa")

#3
numeros = [4,77,3]
for number in numeros:
    print(number+2)

#4
materias = ["matematica", "lengua", "ingles", "historia", "educacion fisica"]
totalmaterias=0
for materia in materias:
    totalmaterias+=1



#5
def dividir(x,y):
    return x/y

#6
def dividirseguro(x,y):
    if y==0:
        print("no se puede dividir por 0")
    else:
        return x/y

#7
def agregar(plist,pnum):
    plist.append(pnum)
# Out:
# los dos numeros son diferentes
# podemos ir a la plaza
# 6
# 79
# 5

# %% [markdown]
# ### Ejercicios Dataset pandas
#
# Para estos ejercicios utilizaremos un dataset extraído de https://data.buenosaires.gob.ar/dataset/plan-de-vacunacion-covid-19 con la información de las vacunas dadas en la Ciudad de Buenos Aires entre el 8/3/2021 hasta el 31/01/22

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google'

# %%
data = pd.read_csv("/content/drive/MyDrive/Aprender Programando/2022/Guías y Recursos - Trayectos 2021/Recursos/Modulos 1 y 2. Presentación CABA/Ciencia de datos/2022/Módulo 1/dataset_total_vacunas.csv")

# %%
data
# Out:
#                                     FECHA_ADMINISTRACION GRUPO_ETARIO GENERO  \
# 0                                     08JAN2021:00:00:00      41 a 50      F
# 1                                     08JAN2021:00:00:00      41 a 50      M
# 2                                     08JAN2021:00:00:00      41 a 50      M
# 3                                     08JAN2021:00:00:00      41 a 50      M
# 4                                     08JAN2021:00:00:00      51 a 60      F
# ...                                                  ...          ...    ...
# 27806  31JAN2022:00:00:00,51 a 60,M,"vacuna Coronavir...          NaN    NaN
# 27807                                 31JAN2022:00:00:00      61 a 70      F
# 27808                                 31JAN2022:00:00:00      61 a 70      F
# 27809                                 31JAN2022:00:00:00      61 a 70      F
# 27810                                 31JAN2022:00:00:00      61 a 70      F
#
# ...

# %%
originaldata = pd.read_csv("datasetproyecto.csv")

# %% [markdown]
# #### Ejercicios pandas 1: exploración

# %% [markdown]
# 1. Ver las 3 útlimas filas del dataset.
#
# 2. Ver el tamaño del dataset
#
# 2. Ver los nombres de las columnas
#
# 3. Seleccionar la columna "TIPO_EFECTOR". Ver que valores toma esa columna y cuántos registros hay de cada uno.
#
# 3. ¿Cuál es el registro en el que se dieron mayor cantidad de vacunas de DOSIS_1? ¿Cuántas vacunas se dieron? ¿Y de DOSIS_2?
#
# 4. Eliminar la columna "ID_CARGA
#
# 5. Cambiar los nombres de todas las columnas a minuscula

# %%
data = originaldata.copy() 


#1
data.tail(3)
#2
len(data)
data.shape[0]
#3
data.columns
#4
data.groupby("TIPO_EFECTOR").size()
#5
data["DOSIS_1"].idxmax()
data["DOSIS_1"].max()
data["DOSIS_2"].idxmax()
data["DOSIS_2"].max()
#6
data.drop(columns="ID_CARGA")
#7
lowercasedict = dict()
for column in data.columns:
    lowercasedict[column]=column.lower()
data.rename(columns=lowercasedict, inplace=True)

# %% [markdown]
# #### Ejercicios pandas 2: filtrar y agrupar

# %% [markdown]
# 1. Crear un nuevo Dataframe solamente con las vacunas aplicadas en Efectores Públicos.
#
# 2. Crear un nuevo Dataframe solamente con las vacunas aplicadas a personas de entre 41 a 50 años.
#
# 3. Calcular cuántas vacunas DOSIS_1 "Sinopharm" se dieron en efectores Públicos. Hacer con dos filtros, debe usarse el signo "&" y colocar cada uno entre parentesis: [(filtro1) & (filtro2)]
#
# 4. Calcular cuántas vacunas "Sputik" DOSIS_2 se dieron a mujeres.
#
# 5. Generar un Dataframe con la cantidad de vacunas DOSIS_1 que se dieron para mujeres. Y generar otro Dataframe para hombres. Usar groupby.
#
# 6. Generar un Dataframe que tenga la cantidad de vacunas DOSIS_1 aplicadas a mujeres y hombres de cada tipo de vacuna. Usar groupby.
#
# 7. Calcular cuántas vacunas de DOSIS_1 y cuantas vacunas de DOSIS_2 se dieron en cada efector, y en total (sumadas las dos).

# %%
#1
filtropublico = originaldata["TIPO_EFECTOR"]=="Público" #suponiendo que no queremos los publicos nacionales
data2=originaldata.loc[filtropublico]

#2

filtropublico = originaldata["GRUPO_ETARIO"]=="41 a 50"
data3=originaldata.loc[filtropublico]

#3

filtropublico = (originaldata["VACUNA"]=="Sinopharm") & (originaldata["TIPO_EFECTOR"]=="Público") #suponiendo que no queremos los publicos nacionales
data4=originaldata.loc[filtropublico]
data4["DOSIS_1"].sum()+data4["DOSIS_2"].sum()+data4["DOSIS_3"].sum()


#4
filtropublico = (originaldata["VACUNA"]=="Sputnik") & (originaldata["GENERO"]=="F") 
data5.loc[filtropublico]["DOSIS_2"].sum()

#5
mujeres = originaldata.groupby("GENERO").get_group("F")
hombres = originaldata.groupby("GENERO").get_group("M")

#6
data_genero_vacuna=originaldata.groupby(["GENERO","VACUNA" ]).sum()["DOSIS_1"]

#7
xefector=originaldata.groupby("TIPO_EFECTOR")
xes=xefector.sum()[["DOSIS_1","DOSIS_2"]]
xes["DOSIS_1+2"]=(xes["DOSIS_1"]+xes["DOSIS_2"])
xes
# Out:
#                     DOSIS_1    DOSIS_2  DOSIS_1+2
# TIPO_EFECTOR
# Privado             98392.0    64237.0   162629.0
# Público           2538616.0  2428006.0  4966622.0
# Público nacional    13175.0     7222.0    20397.0

# %% [markdown]
# #### Ejercicios opcionales
#
# Usar estructuras de control en DataFrames

# %% [markdown]
# 1. Utilizar una iteración *(for)* para ver el registro con mayor cantidad de DOSIS_1 en cada Efector.
#
# 2. Utilizar una iteración *(for)* para generar un Dataframe solo con los registros de mujeres y otro solo con los registros de los hombres.
#
# 3. Crear una función *(def)* que reciba como parámetro la "VACUNA" y devuelva la cantidad de DOSIS_1 que se dieron a mujeres.
#
# 4. Crear una función *(def)* que reciba como parámetro el género y devuelva la la cantidad de DOSIS_2 que se dieron.
#
# 5. Crear una función *(def)* que reciba como parámetro el Tipo de Efector y devuelva la cantidad de registros que hay en cada uno.
#
# 6. Utilizar un condicional *(if)* que sume la cantidad de vacunas DOSIS_1 aplicadas a hombres y la cantidad de vacunas DOSIS_2 aplicadas a mujeres.
#
# 7. Utilizar un condicional *(if)* que sume la cantidad de vacunas DOSIS_1 y DOSIS_2 en el caso de Efectores Públicos, solo las DOSIS_1 en el caso de EFectores Privados y solo DOSIS_2 en el caso de Efectores Público Nacional
#
# 8. Utilizar un condicional *(if)* que calcule la cantidad de vacunas DOSIS_1 de "Sputnik", DOSIS_2 de "Sinopharm" y la suma de las dos dosis de "Aztrazeneca"
#
# 9. Hacer una función *(def)* que reciba como parámetro un rango de edad y utilizando un condicional *(if)* devuelva la cantidad de vacunas DOSIS_1 aplicadas en el caso de las mujeres y DOSIS_2 en el caso de hombres.
#
# 10. Hacer una función que reciba como parámetro un rango de edad y a través de una interación devuelva la cantidad de vacunas aplicadas DOSIS_1 y DOSIS_2.
#
# 11. Hacer una función *(def)* que reciba como parámetro un rango de edad y utilizando un condicional *(if)* devuelva la cantidad de vacunas DOSIS_1 aplicadas en el caso de las mujeres y DOSIS_2 en el caso de hombres.

# %%
#1

dmax=originaldata.iloc[0]
for i,x in originaldata.iterrows():
    if dmax["DOSIS_1"]<x["DOSIS_1"]:
        dmax=x
    
dmax

#2
"""
hombres2=pd.DataFrame(dict(zip(originaldata.columns, [[]]*len(originaldata.columns))))
mujeres2=hombres.copy()

for i,x in originaldata.iterrows():
    if x["GENERO"]=="M":
        hombres2=pd.concat([hombres2,x])
    elif x["GENERO"]=="F":
        mujeres2=pd.concat([mujeres2,x])
"""
        


#3
# Out:
#                       FECHA_ADMINISTRACION  GRUPO_ETARIO  GENERO  VACUNA  \
# FECHA_ADMINISTRACION                   NaN           NaN     NaN     NaN
# GRUPO_ETARIO                           NaN           NaN     NaN     NaN
# GENERO                                 NaN           NaN     NaN     NaN
# VACUNA                                 NaN           NaN     NaN     NaN
# TIPO_EFECTOR                           NaN           NaN     NaN     NaN
# ...                                    ...           ...     ...     ...
# TIPO_EFECTOR                           NaN           NaN     NaN     NaN
# DOSIS_1                                NaN           NaN     NaN     NaN
# DOSIS_2                                NaN           NaN     NaN     NaN
# ID_CARGA                               NaN           NaN     NaN     NaN
# DOSIS_3                                NaN           NaN     NaN     NaN
#
#                       TIPO_EFECTOR  DOSIS_1  DOSIS_2  ID_CARGA  DOSIS_3  \
# ...
